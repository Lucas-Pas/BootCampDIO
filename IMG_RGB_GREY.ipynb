# %% [markdown]
# <a href="https://colab.research.google.com/github/Lucas-Pas/BootCampDIO/blob/main/IMG_RGB_GREY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -o 'imagem.jpg' 'https://chefbob.com.br/wp-content/uploads/2021/05/2021-05-12-como-deixar-os-gatos-mais-tranquilos.jpg'

# %%
from PIL import Image
import requests

# %%
def GRAYS_color(colored):
    w, h = colored.size

    for x in range(w):
        for y in range(h):
            pxl = colored.getpixel((x, y))
            lum = (pxl[0] + pxl[1] + pxl[2])//3
            img.putpixel((x, y), (lum, lum, lum))
    return img

# %%
def BLACK_and_WHITE(gray):
    w, h = gray.size

    for x in range(w):
        for y in range(h):
            pxl = gray.getpixel((x, y))
            if pxl[0] >= 160:
                gray.putpixel((x, y), (255, 255, 255))
            else:
                gray.putpixel((x, y), (0, 0, 0))
    return gray

# %%
url = 'https://chefbob.com.br/wp-content/uploads/2021/05/2021-05-12-como-deixar-os-gatos-mais-tranquilos.jpg'

img = Image.open(requests.get(url, stream=True).raw)

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=968x506>

# %%
grey = GRAYS_color(img)

grey
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=968x506>

# %%
black_white = BLACK_and_WHITE(grey)

black_white
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=968x506>
